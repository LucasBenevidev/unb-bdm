# %%
# !python ../scripts/trino/create_iceberg_tables.py
# !python ../scripts/trino/load_s3_to_iceberg.py --mode recreate
# !python ../validate_iceberg_data.py
